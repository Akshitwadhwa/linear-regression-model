# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# here we have imported the neccesary library

# %%
trained_data = pd.read_csv('datasets/california_linear.csv')
trained_data
# this is the trained data which has the new varibles in it  
# we see that we got the inland , island and the near bay varibales
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.70     39.14                13.0     6.278521        4.718499
# 1        -121.96     37.85                10.0     8.074026        5.940171
# 2        -122.69     38.44                31.0     7.500529        5.755742
# 3        -118.45     34.02                41.0     7.991931        6.552508
# 4        -118.35     33.96                26.0     7.928046        6.525030
# ...          ...       ...                 ...          ...             ...
# 16341    -120.90     35.33                16.0     7.363280        5.662960
# 16342    -116.99     32.72                15.0     6.716595        4.875197
# 16343    -119.90     36.20                43.0     5.236442        3.663562
# 16344    -122.48     37.75                52.0     7.830426        6.204558
# 16345    -120.07     36.96                32.0     7.145984        5.648974
#
# ...

# %%
from sklearn.model_selection import train_test_split

x = trained_data.drop(['median_house_value'], axis=1)
y = trained_data['median_house_value']
# here we have made the x and y trai

# %%
X_train , X_test , y_train , y_test = train_test_split(x , y ,test_size=0.2)
trained_data = X_train.join(y_train)
# using this we are going to x train and y train mechanism where we have taken the size of 0.2
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12339    -118.46     34.07                49.0     7.791110        5.710427
# 7694     -117.87     33.70                21.0     8.202208        6.484635
# 3719     -118.49     34.03                30.0     8.309431        6.833032
# 5317     -117.39     33.96                52.0     7.597396        5.846439
# 6562     -118.38     33.75                23.0     9.021357        7.163172
# ...          ...       ...                 ...          ...             ...
# 7862     -118.30     34.06                20.0     7.486053        6.799056
# 4695     -118.39     33.96                45.0     7.216709        5.533389
# 9194     -117.93     33.74                30.0     7.411556        6.075346
# 6015     -118.18     34.02                35.0     6.495266        4.962845
# 3874     -118.31     34.12                39.0     8.267706        6.331502
#
# ...

# %% [markdown]
# # Now we are going to make the linear regreassion plot after this

# %%
from sklearn.linear_model import LinearRegression

X_train , y_train = trained_data.drop(['median_house_value'],axis = 1), trained_data['median_house_value']
# here we have taken the 
reg = LinearRegression()
# loading the liner regression model and library

reg.fit(X_train , y_train)
# building upon the linear regression model
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
# using the trained data in the previous code
test_data['total_rooms'] = np.log(test_data['total_rooms'] +1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] +1)
test_data['population'] = np.log(test_data['population'] +1)
test_data['households'] = np.log(test_data['households'] +1)

test_data['bedroom_ratio'] = test_data['total_bedrooms']/ test_data['total_rooms']
test_data['household_room'] = test_data['total_rooms'] / test_data['households']
# here we have tested the data and made the new data

# %%
trained_data
# we can see that in the end we have created
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12339    -118.46     34.07                49.0     7.791110        5.710427
# 7694     -117.87     33.70                21.0     8.202208        6.484635
# 3719     -118.49     34.03                30.0     8.309431        6.833032
# 5317     -117.39     33.96                52.0     7.597396        5.846439
# 6562     -118.38     33.75                23.0     9.021357        7.163172
# ...          ...       ...                 ...          ...             ...
# 7862     -118.30     34.06                20.0     7.486053        6.799056
# 4695     -118.39     33.96                45.0     7.216709        5.533389
# 9194     -117.93     33.74                30.0     7.411556        6.075346
# 6015     -118.18     34.02                35.0     6.495266        4.962845
# 3874     -118.31     34.12                39.0     8.267706        6.331502
#
# ...

# %% [markdown]
# # Now we are going to make a plot for the main variable or the target variable.

# %%
# Let us take the target variable as the median_house_value

mean_house_value = trained_data['median_house_value'].mean().round(0)
