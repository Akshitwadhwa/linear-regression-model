# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# here we have imported the neccesary library

# %%
trained_data = pd.read_csv('datasets/california_linear.csv')
trained_data
# this is the trained data which has the new varibles in it  
# we see that we got the inland , island and the near bay varibales
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.70     39.14                13.0     6.278521        4.718499
# 1        -121.96     37.85                10.0     8.074026        5.940171
# 2        -122.69     38.44                31.0     7.500529        5.755742
# 3        -118.45     34.02                41.0     7.991931        6.552508
# 4        -118.35     33.96                26.0     7.928046        6.525030
# ...          ...       ...                 ...          ...             ...
# 16341    -120.90     35.33                16.0     7.363280        5.662960
# 16342    -116.99     32.72                15.0     6.716595        4.875197
# 16343    -119.90     36.20                43.0     5.236442        3.663562
# 16344    -122.48     37.75                52.0     7.830426        6.204558
# 16345    -120.07     36.96                32.0     7.145984        5.648974
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0        5.370638    4.143135         3.3929            108300.0          0
# 1        7.090077    5.973810        12.2478            500001.0          0
# 2        6.539586    5.638355         3.8583            193200.0          1
# 3        7.100852    6.470800         3.4583            421900.0          1
# 4        7.353082    6.448889         3.1354            164300.0          1
# ...           ...         ...            ...                 ...        ...
# 16341    6.390241    5.572154         3.5880            266300.0          0
# 16342    5.814131    4.882802         4.0391            169500.0          1
# 16343    4.672829    3.713572         1.8750            137500.0          0
# 16344    7.367709    6.169611         4.3393            317600.0          0
# 16345    6.309918    5.613128         1.4511             65200.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0           1       0         0           0
# 1           1       0         0           0
# 2           0       0         0           0
# 3           0       0         0           0
# 4           0       0         0           0
# ...       ...     ...       ...         ...
# 16341       0       0         0           1
# 16342       0       0         0           0
# 16343       1       0         0           0
# 16344       0       0         1           0
# 16345       1       0         0           0
#
# [16346 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

x = trained_data.drop(['median_house_value'], axis=1)
y = trained_data['median_house_value']
# here we have made the x and y trai

# %%
X_train , X_test , y_train , y_test = train_test_split(x , y ,test_size=0.2)
trained_data = X_train.join(y_train)
# using this we are going to x train and y train mechanism where we have taken the size of 0.2
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4795     -117.97     33.91                19.0     8.999249        7.184629
# 561      -122.37     37.95                35.0     5.375278        3.828641
# 15661    -119.34     36.62                26.0     7.561642        5.828946
# 15403    -121.46     38.52                29.0     8.262043        6.682109
# 14576    -121.87     36.55                20.0     9.215726        7.478170
# ...          ...       ...                 ...          ...             ...
# 9        -124.16     40.79                52.0     7.142827        5.627621
# 16281    -117.58     33.87                30.0     6.553933        4.882802
# 13530    -118.36     34.03                43.0     7.433075        5.940171
# 14243    -118.18     34.03                39.0     6.413459        4.983607
# 3813     -121.44     39.50                26.0     7.410347        5.786897
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 4795     8.256867    7.180831         6.0076          1       0       0
# 561      4.615121    3.555348         1.6023          0       0       0
# 15661    7.046647    5.808142         2.6058          0       1       0
# 15403    7.713338    6.561031         2.1736          0       1       0
# 14576    8.033983    7.391415         5.1506          0       0       0
# ...           ...         ...            ...        ...     ...     ...
# 9        6.383507    5.652489         1.7778          0       0       0
# 16281    5.877736    4.836282         3.2917          0       1       0
# 13530    6.925595    5.886104         2.1078          1       0       0
# 14243    6.538140    4.905275         2.9167          1       0       0
# 3813     6.673298    5.680173         3.0446          0       1       0
#
#        NEAR BAY  NEAR OCEAN  median_house_value
# 4795          0           0            269500.0
# 561           1           0             81300.0
# 15661         0           0             92200.0
# 15403         0           0             72100.0
# 14576         0           1            387500.0
# ...         ...         ...                 ...
# 9             0           1             76900.0
# 16281         0           0            144300.0
# 13530         0           0            133500.0
# 14243         0           0            145800.0
# 3813          0           0             90800.0
#
# [13076 rows x 14 columns]

# %% [markdown]
# # Now we are going to make the linear regreassion plot after this

# %%
from sklearn.linear_model import LinearRegression

X_train , y_train = trained_data.drop(['median_house_value'],axis = 1), trained_data['median_house_value']
# here we have taken the 
reg = LinearRegression()
# loading the liner regression model and library

reg.fit(X_train , y_train)
# building upon the linear regression model
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
# using the trained data in the previous code
test_data['total_rooms'] = np.log(test_data['total_rooms'] +1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] +1)
test_data['population'] = np.log(test_data['population'] +1)
test_data['households'] = np.log(test_data['households'] +1)

test_data['bedroom_ratio'] = test_data['total_bedrooms']/ test_data['total_rooms']
test_data['household_room'] = test_data['total_rooms'] / test_data['households']
# here we have tested the data and made the new data

# %%
trained_data
# we can see that in the end we have created
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4795     -117.97     33.91                19.0     2.302510        2.102258
# 561      -122.37     37.95                35.0     1.852428        1.574565
# 15661    -119.34     36.62                26.0     2.147292        1.921170
# 15403    -121.46     38.52                29.0     2.225925        2.038894
# 14576    -121.87     36.55                20.0     2.323928        2.137495
# ...          ...       ...                 ...          ...             ...
# 9        -124.16     40.79                52.0     2.097137        1.891246
# 16281    -117.58     33.87                30.0     2.022068        1.772033
# 13530    -118.36     34.03                43.0     2.132162        1.937326
# 14243    -118.18     34.03                39.0     2.003297        1.789024
# 3813     -121.44     39.50                26.0     2.129463        1.914994
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 4795     2.225366    2.101794         6.0076          1       0       0
# 561      1.725463    1.516302         1.6023          0       0       0
# 15661    2.085256    1.918119         2.6058          0       1       0
# 15403    2.164855    2.023008         2.1736          0       1       0
# 14576    2.200993    2.127209         5.1506          0       0       0
# ...           ...         ...            ...        ...     ...     ...
# 9        1.999249    1.894991         1.7778          0       0       0
# 16281    1.928289    1.764094         3.2917          0       1       0
# 13530    2.070097    1.929505         2.1078          1       0       0
# 14243    2.019975    1.775846         2.9167          1       0       0
# 3813     2.037747    1.899144         3.0446          0       1       0
#
#        NEAR BAY  NEAR OCEAN  median_house_value
# 4795          0           0            269500.0
# 561           1           0             81300.0
# 15661         0           0             92200.0
# 15403         0           0             72100.0
# 14576         0           1            387500.0
# ...         ...         ...                 ...
# 9             0           1             76900.0
# 16281         0           0            144300.0
# 13530         0           0            133500.0
# 14243         0           0            145800.0
# 3813          0           0             90800.0
#
# [13076 rows x 14 columns]
